# %% [markdown]
# <a href="https://colab.research.google.com/github/LK920/tesorflow/blob/master/tf12_auto_encoder_test3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 20/08/25

내용 : 오토인코더 활용 - 이미지 노이즈 제거
"""

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Model

# %%
#MLIST 데이터셋 로드
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train.shape, y_train.shape
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# ((60000, 28, 28), (60000,))

# %%
#데이터 전처리
x_train = x_train.reshape(-1, 28, 28,1) /255.0
x_test = x_test.reshape(-1, 28, 28,1) /255.0

x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
#노이즈 이미지 생성
x_train_random = np.random.normal(0,1, x_train.shape)
x_test_random = np.random.normal(0,1, x_test.shape)

train_noisy = np.clip(x_train+x_train_random*0.4, 0,1)
test_noisy = np.clip(x_test+x_test_random*0.4, 0,1)

# %%
#노이즈 이미지 출력
plt.figure(figsize=(20,4))

for i in range(10):
  #오리지날 이미지

  ax = plt.subplot(2,10,i+1)
  ax.set_title('original image')
  plt.imshow(x_train[i].reshape(28,28))
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  #result image
  ax = plt.subplot(2,10,i+11)
  ax.set_title('noisy image')
  plt.imshow(train_noisy[i].reshape(28,28))
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

# %%
#모델 구성
inputs = Input(shape=(28,28,1))#28*28 1장짜리 이미지로
encoding_layout = Conv2D(filters=32, kernel_size=2, strides=2, padding='same', activation='relu')(inputs)#strides 이동 2칸씩
encoding_layout = MaxPool2D(pool_size=1, strides=2, padding='same')(encoding_layout)
encoding_layout = Conv2D(filters=32, kernel_size=2, strides=1, padding='same', activation='relu')(encoding_layout)

decoding_layout = Conv2DTranspose(filters=32, kernel_size=2, strides=2, padding='same', activation='relu')(encoding_layout)
outs = Conv2DTranspose(filters=1, kernel_size=2, strides=2, padding='same', activation='relu')(decoding_layout)

auto_encoder = Model(inputs, outs)
auto_encoder.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 32)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 7, 7, 32)          0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 32)          4128
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 32)        4128
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 1)         129
# =================================================================
# Total params: 8,545
# Trainable params: 8,545
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 설정/학습하기
auto_encoder.compile(optimizer='adam', loss='binary_crossentropy')
auto_encoder.fit(train_noisy, x_train, epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1877
# Epoch 2/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1848
# Epoch 3/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1857
# Epoch 4/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1884
# Epoch 5/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1865
# Epoch 6/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1886
# Epoch 7/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1874
# Epoch 8/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1854
# Epoch 9/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1863
# Epoch 10/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1859
# Epoch 11/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1847
# Epoch 12/20
# 1875/1875 [==============================] - 24s 13ms/step - loss: 0.1862
# Epoch 13/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1873
# Epoch 14/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1844
# Epoch 15/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1836
# Epoch 16/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1837
# Epoch 17/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1834
# Epoch 18/20
# 1875/1875 [==============================] - 23s 12ms/step - loss: 0.1841
# Epoch 19/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1846
# Epoch 20/20
# 1875/1875 [==============================] - 22s 12ms/step - loss: 0.1835

# %%
#예측하기
result = auto_encoder.predict(test_noisy)
result.shape
# Out:
# (10000, 28, 28, 1)

# %%
#결과 이미지 출력
plt.figure(figsize=(20,4))

for i in range(10):
  
  #노이즈 이미지
  ax = plt.subplot(2,10,i+1)
  ax.set_title('noisy image')
  plt.imshow(test_noisy[i].reshape(28,28))
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)

  #result image
  ax = plt.subplot(2,10,i+11)
  ax.set_title('result image')
  plt.imshow(result[i].reshape(28,28))
  plt.gray()
  ax.get_xaxis().set_visible(False)
  ax.get_yaxis().set_visible(False)
